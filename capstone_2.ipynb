# %%
import pandas as pd 
import numpy as np

# %%
customers=pd.read_csv('Customers.csv', encoding='ISO-8859-1')
exchange_rates=pd.read_csv('Exchange_Rates.csv')
products=pd.read_csv('Products.csv')
stores=pd.read_csv('Stores.csv')
sales=pd.read_csv('sales.csv')

# %%
customers.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
customers.isnull()
# Out:
#        CustomerKey  Gender   Name   City  State Code  State  Zip Code  \
# 0            False   False  False  False       False  False     False
# 1            False   False  False  False       False  False     False
# 2            False   False  False  False       False  False     False
# 3            False   False  False  False       False  False     False
# 4            False   False  False  False       False  False     False
# ...            ...     ...    ...    ...         ...    ...       ...
# 15261        False   False  False  False       False  False     False
# 15262        False   False  False  False       False  False     False
# 15263        False   False  False  False       False  False     False
# 15264        False   False  False  False       False  False     False
# 15265        False   False  False  False       False  False     False
#
#        Country  Continent  Birthday
# 0        False      False     False
# 1        False      False     False
# ...

# %%
customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
missing_data = customers[customers['State Code'].isna()]
missing_data
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
customers['State Code'] = customers['State Code'].fillna('NA')

# %%
customers['Birthday'] = pd.to_datetime(customers['Birthday'], format='%m/%d/%Y', errors='coerce')

# %%
customers.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
exchange_rates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
exchange_rates.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exchange_rates['Date'] = pd.to_datetime(exchange_rates['Date'], format='%m/%d/%Y', errors='coerce')

# %%
exchange_rates.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
products['Unit Cost USD'] = products['Unit Cost USD'].replace(r'[\$,]', '', regex=True).astype(float)
products['Unit Price USD'] = products['Unit Price USD'].replace(r'[\$,]', '', regex=True).astype(float)

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
stores.dtypes
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %%
stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
stores['Open Date'] = pd.to_datetime(stores['Open Date'], format='%m/%d/%Y', errors='coerce')

# %%
stores.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
stores['Square Meters']=stores['Square Meters'].fillna('0')

# %%
stores
# Out:
#     StoreKey        Country                         State Square Meters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online             0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ...

# %%
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'], format='%m/%d/%Y')
sales['Delivery Date'] = pd.to_datetime(sales['Delivery Date'], format='%m/%d/%Y', errors='coerce')

# %%
sales['Delivery Date']=sales['Delivery Date'].fillna('Not Available')

# %%
sales
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# ...

# %%
sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date            object
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
products.dtypes

# %%
customers.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
stores.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters            object
# Open Date        datetime64[ns]
# dtype: object

# %%
exchange_rates.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object

# %%
import pandas as pd

# Assuming the datasets are stored in the following dataframes:
# orders_df, products_df, customers_df, stores_df, exchange_rates_df

# 1. Merge Orders with Customers on 'CustomerKey'
merged_data = pd.merge(sales, customers, on='CustomerKey', how='left')

# 2. Merge Orders-Customers with Stores on 'StoreKey'
merged_data = pd.merge(merged_data, stores, on='StoreKey', how='left')

# 3. Merge Orders-Customers-Stores with Products on 'ProductKey'
merged_data = pd.merge(merged_data, products, on='ProductKey', how='left')

# 4. Merge Orders-Customers-Stores-Products with Currency Exchange
# We need to match both the 'Currency Code' and 'Order Date' for an accurate exchange rate.
merged_data = pd.merge(merged_data, exchange_rates, 
                     left_on=['Currency Code', 'Order Date'], 
                     right_on=['Currency', 'Date'], 
                     how='left')

# %%
# Drop the redundant columns after merge if needed
merged_data.drop(columns=['Currency', 'Date'], inplace=True)

# Now merged_df contains all the data merged from the five datasets.

# %%
merged_data.head()
# Out:
#    Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0        366000          1 2016-01-01        Not Available       265598
# 1        366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2        366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3        366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4        366002          2 2016-01-01  2016-01-12 00:00:00       266019
#
#    StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# 0        10        1304         1           CAD    Male  ...
# 1         0        1048         2           USD    Male  ...
# 2         0        2007         1           USD    Male  ...
# 3         0        1106         7           CAD  Female  ...
# 4         0         373         1           CAD  Female  ...
#
#                              Product Name            Brand   Color  \
# 0         Contoso Lens Adapter M450 White          Contoso   White
# ...

# %%
df = pd.DataFrame(merged_data)
file_name = 'merged_data.csv'
df.to_csv(file_name, index=False)

# %%
merged_data.dtypes
# Out:
# Order Number               int64
# Line Item                  int64
# Order Date        datetime64[ns]
# Delivery Date             object
# CustomerKey                int64
# StoreKey                   int64
# ProductKey                 int64
# Quantity                   int64
# Currency Code             object
# Gender                    object
# Name                      object
# City                      object
# State Code                object
# State_x                   object
# Zip Code                  object
# Country_x                 object
# Continent                 object
# Birthday          datetime64[ns]
# Country_y                 object
# State_y                   object
# Square Meters             object
# Open Date         datetime64[ns]
# Product Name              object
# Brand                     object
# Color                     object
# Unit Cost USD            float64
# Unit Price USD           float64
# SubcategoryKey             int64
# ...

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
 
host = "localhost"
port = "3306"
username = "chakradhar"
password = "chakradhar123456789"
database = "GE"
 
engine_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(engine_string)
 
table_name = "merged_data"
merged_data.to_sql(table_name, engine,if_exists='replace',index=False)

table_name = "customers"
customers.to_sql(table_name, engine,if_exists='replace',index=False)

table_name = "products"
products.to_sql(table_name, engine,if_exists='replace',index=False)

table_name = "exchangerates"
exchange_rates.to_sql(table_name, engine,if_exists='replace',index=False)

table_name = "stores"
stores.to_sql(table_name, engine,if_exists='replace',index=False)

table_name = "sales"
sales.to_sql(table_name, engine,if_exists='replace',index=False)
# Out:
# 62884
